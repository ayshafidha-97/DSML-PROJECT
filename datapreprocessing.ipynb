# %% [markdown]
# <a href="https://colab.research.google.com/github/ayshafidha-97/DSML-PROJECT/blob/main/datapreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
df.isnull().sum()
df = df.drop_duplicates()
df = df.fillna(df.median(numeric_only=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   0 non-null      object
#  1   dateAdded            0 non-null      object
#  2   dateUpdated          0 non-null      object
#  3   name                 0 non-null      object
#  4   asins                0 non-null      object
#  5   brand                0 non-null      object
#  6   categories           0 non-null      object
#  7   primaryCategories    0 non-null      object
#  8   imageURLs            0 non-null      object
#  9   keys                 0 non-null      object
#  10  manufacturer         0 non-null      object
#  11  manufacturerNumber   0 non-null      object
#  12  reviews.date         0 non-null      object
#  13  reviews.dateAdded    0 non-null      object
#  14  reviews.dateSeen     0 non-null      object
# ...

# %%
df.describe()
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <Axes: >

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/PROJECT/Customer Purchase Prediction And Recommendation system for E commerce/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns
print("Categorical Columns:", categorical_cols.tolist())
# Out:
# Categorical Columns: ['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand', 'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer', 'manufacturerNumber', 'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen', 'reviews.sourceURLs', 'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le
df.head()
# Out:
#    id  dateAdded  dateUpdated  name  asins  brand  categories  \
# 0  11          9           16    11      5      0           7
# 1  11          9           16    11      5      0           7
# 2  11          9           16    11      5      0           7
# 3  11          9           16    11      5      0           7
# 4  11          9           16    11      5      0           7
#
#    primaryCategories  imageURLs  keys  ...  reviews.dateSeen  \
# 0                  0         15     7  ...               411
# 1                  0         15     7  ...               405
# 2                  0         15     7  ...               381
# 3                  0         15     7  ...               415
# 4                  0         15     7  ...               381
#
#    reviews.doRecommend   reviews.id  reviews.numHelpful  reviews.rating  \
# 0                False          NaN                   0               3
# 1                 True          NaN                   0               5
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/PROJECT/Customer Purchase Prediction And Recommendation system for E commerce/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
numerical_cols = df.select_dtypes(include=np.number).columns


for col in numerical_cols[:3]:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot for {col}')
    plt.show()

# %%
df.select_dtypes(include='number').columns.tolist()
# Out:
# ['reviews.id', 'reviews.numHelpful', 'reviews.rating']

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]

outliers = detect_outliers_iqr(df,'reviews.id')
print(outliers)
# Out:
#                       id             dateAdded           dateUpdated  \
# 21  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 70  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 77  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                  name       asins   brand  \
# 21  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 70  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 77  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                            categories primaryCategories  \
# 21  Computers,Electronics Features,Tablets,Electro...       Electronics
# 70  Computers,Electronics Features,Tablets,Electro...       Electronics
# 77  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                             imageURLs  \
# ...

# %%
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

df = remove_outliers_iqr(df, 'reviews.id')
def cap_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data[column] = np.where(data[column] > upper_bound, upper_bound,
                            np.where(data[column] < lower_bound, lower_bound, data[column]))
    return data

df = cap_outliers_iqr(df, 'reviews.id')
sns.boxplot(x=df['reviews.id'])
plt.title("After Outlier Handling")
plt.show()
# Out:
# /tmp/ipython-input-30-3088809057.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = np.where(data[column] > upper_bound, upper_bound,

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = '/content/drive/MyDrive/PROJECT/Customer Purchase Prediction And Recommendation system for E commerce/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
df.info()
df = df.dropna()

if 'Order Date' in df.columns:
     df['Order Date'] = pd.to_datetime(df['Order Date'])
df.columns = df.columns.str.strip().str.replace(' ', '_')

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5000 non-null   object
#  1   dateAdded            5000 non-null   object
#  2   dateUpdated          5000 non-null   object
#  3   name                 5000 non-null   object
#  4   asins                5000 non-null   object
#  5   brand                5000 non-null   object
#  6   categories           5000 non-null   object
#  7   primaryCategories    5000 non-null   object
#  8   imageURLs            5000 non-null   object
#  9   keys                 5000 non-null   object
#  10  manufacturer         5000 non-null   object
#  11  manufacturerNumber   5000 non-null   object
#  12  reviews.date         5000 non-null   object
#  13  reviews.dateAdded    1052 non-null   object
#  14  reviews.dateSeen     5000 non-null   object
# ...

# %%
if 'Sales' in df.columns and 'Month' in df.columns:
    monthly_sales = df.groupby('Month')['Sales'].sum()

    plt.figure(figsize=(12, 6))
    monthly_sales.plot(kind='line', marker='o')
    plt.title("Monthly Sales Trend")
    plt.xlabel("Month")
    plt.ylabel("Sales")
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()

if 'Category' in df.columns:
    plt.figure(figsize=(8,5))
    sns.barplot(data=df, x='Category', y='Sales', estimator=sum)
    plt.title('Total Sales by Category')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


    if 'Profit' in df.columns and 'Category' in df.columns:
     plt.figure(figsize=(8,5))
    sns.boxplot(x='Category', y='Profit', data=df)
    plt.title("Profit Distribution by Category")
    plt.xticks(rotation=45)
    plt.show()
    plt.figure(figsize=(10, 6))

sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(df.columns.tolist())



plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='reviews.id', y='reviews.rating')
plt.title('Profit Distribution by name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand', 'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer', 'manufacturerNumber', 'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen', 'reviews.doRecommend', 'reviews.id', 'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs', 'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='brand', y='categories')
plt.title('Profit Distribution by brand')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-31-3147840551.py:8: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='brand', y='primaryCategories')
plt.title('Sales Distribution by brand')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='asins', y='brand')
plt.title('Sales Distribution by categories')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='name', y='primaryCategories')
plt.title('Sales Distribution by name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-40-3070231969.py:5: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
